# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import random

# %%
random.seed(24)

# %% [markdown]
# # Dog Shelter Adoption Predictor#

# %% [markdown]
# ### Introduction ###
#
# Adopting a dog is no simple decision, there are a lot of factors that should be taken into account. Some future owners look for dogs whose lifestyle needs would align with their own. Some need a working group dog to do a job. Some just look for aesthetics. In this project I am trying to find a set of traits, even within mixed breed shelter dogs, that might predict the length of their shelter stay. What makes a dog "adoptable"?

# %% [markdown]
# ## Reading datasets: ##
#
# <ol>
#     <li>Shelter Animal Stays [1]</li>
#     <li>Dog Breeds [2]</li>
#
# </ol>
# <br>
#     In the following part I am using the data for shelter animal stay (animal X appears in N rows for each one of its N stays in the shelter) to get a dataset where every row is a unique <b>dog</b> with information about its shelter history.

# %%
shelter = pd.read_csv('./data/aac_intakes_outcomes.csv')
breeds = pd.read_csv('./data/akc-data-latest.csv')

# %% [markdown]
# <hr/>

# %% [markdown]
# ## 1. Shelter: ##

# %%
shelter = shelter.loc[shelter.animal_type == 'Dog'].copy().drop(['animal_type', 'animal_id_outcome'], axis = 1)
shelter = shelter.rename(mapper = {'animal_id_intake': 'animal_id'}, axis = 1)

# %%
shelter.shape
# Out:
# (45366, 39)

# %%
shelter.head()
# Out:
#   age_upon_outcome        date_of_birth outcome_subtype     outcome_type  \
# 0         10 years  2007-07-09 00:00:00             NaN  Return to Owner
# 1          7 years  2007-07-09 00:00:00             NaN  Return to Owner
# 2          6 years  2007-07-09 00:00:00             NaN  Return to Owner
# 3         10 years  2004-04-02 00:00:00         Partner         Transfer
# 4         16 years  1997-10-16 00:00:00             NaN  Return to Owner
#
#   sex_upon_outcome  age_upon_outcome_(days)  age_upon_outcome_(years)  \
# 0    Neutered Male                     3650                      10.0
# 1    Neutered Male                     2555                       7.0
# 2    Neutered Male                     2190                       6.0
# 3    Neutered Male                     3650                      10.0
# 4    Neutered Male                     5840                      16.0
#
#   age_upon_outcome_age_group     outcome_datetime  outcome_month  ...  \
# 0                (7.5, 10.0]  2017-12-07 14:07:00             12  ...
# 1                 (5.0, 7.5]  2014-12-20 16:35:00             12  ...
# 2                 (5.0, 7.5]  2014-03-08 17:10:00              3  ...
# 3                (7.5, 10.0]  2014-04-07 15:12:00              4  ...
# 4               (15.0, 17.5]  2013-11-16 11:54:00             11  ...
#
#    age_upon_intake_age_group      intake_datetime intake_month  intake_year  \
# 0                (7.5, 10.0]  2017-12-07 00:00:00           12         2017
# 1                 (5.0, 7.5]  2014-12-19 10:21:00           12         2014
# 2                 (5.0, 7.5]  2014-03-07 14:26:00            3         2014
# 3                (7.5, 10.0]  2014-04-02 15:55:00            4         2014
# 4               (15.0, 17.5]  2013-11-16 09:02:00           11         2013
#
#    intake_monthyear  intake_weekday  intake_hour intake_number  \
# 0           2017-12        Thursday           14           1.0
# 1           2014-12          Friday           10           2.0
# 2           2014-03          Friday           14           3.0
# 3           2014-04       Wednesday           15           1.0
# 4           2013-11        Saturday            9           1.0
#
#              time_in_shelter time_in_shelter_days
# 0  0 days 14:07:00.000000000             0.588194
# 1  1 days 06:14:00.000000000             1.259722
# 2  1 days 02:44:00.000000000             1.113889
# 3  4 days 23:17:00.000000000             4.970139
# 4  0 days 02:52:00.000000000             0.119444
#
# [5 rows x 39 columns]

# %%
shelter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45366 entries, 0 to 79671
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age_upon_outcome            45366 non-null  object
#  1   date_of_birth               45366 non-null  object
#  2   outcome_subtype             13768 non-null  object
#  3   outcome_type                45364 non-null  object
#  4   sex_upon_outcome            45365 non-null  object
#  5   age_upon_outcome_(days)     45366 non-null  int64
#  6   age_upon_outcome_(years)    45366 non-null  float64
#  7   age_upon_outcome_age_group  45366 non-null  object
#  8   outcome_datetime            45366 non-null  object
#  9   outcome_month               45366 non-null  int64
#  10  outcome_year                45366 non-null  int64
#  11  outcome_monthyear           45366 non-null  object
#  12  outcome_weekday             45366 non-null  object
#  13  outcome_hour                45366 non-null  int64
#  14  outcome_number              45366 non-null  float64
#  15  dob_year                    45366 non-null  int64
#  16  dob_month                   45366 non-null  int64
#  17  dob_monthyear               45366 non-null  object
#  18  age_upon_intake             45366 non-null  object
#  19  animal_id                   45366 non-null  object
#  20  breed                       45366 non-null  object
#  21  color                       45366 non-null  object
#  22  found_location              45366 non-null  object
#  23  intake_condition            45366 non-null  object
#  24  intake_type                 45366 non-null  object
#  25  sex_upon_intake             45365 non-null  object
#  26  count                       45366 non-null  int64
#  27  age_upon_intake_(days)      45366 non-null  int64
#  28  age_upon_intake_(years)     45366 non-null  float64
#  29  age_upon_intake_age_group   45366 non-null  object
#  30  intake_datetime             45366 non-null  object
#  31  intake_month                45366 non-null  int64
#  32  intake_year                 45366 non-null  int64
#  33  intake_monthyear            45366 non-null  object
#  34  intake_weekday              45366 non-null  object
#  35  intake_hour                 45366 non-null  int64
#  36  intake_number               45366 non-null  float64
#  37  time_in_shelter             45366 non-null  object
#  38  time_in_shelter_days        45366 non-null  float64
# dtypes: float64(5), int64(11), object(23)
# memory usage: 13.8+ MB

# %% [markdown]
# #### Removing duplicate rows and columns: ####

# %%
shelter.loc[shelter.duplicated(keep = False)].sort_values('animal_id').shape[0]
# Out:
# 24

# %%
shelter = shelter.drop_duplicates()

# %%
useless_cols_re = [r'.*_\(days\)|_\(years\)$', r'.*_age_group$', r'.*_month|_year|_monthyear|_hour|_days$', r'^age_upon', 'found_location', 'count']
cols_to_remove = []
for regex in useless_cols_re:
    cols_to_remove += shelter.filter(regex = regex).columns.tolist()

shelter = shelter.drop(cols_to_remove, axis = 1)

# %%
shelter.head()
# Out:
#          date_of_birth outcome_subtype     outcome_type sex_upon_outcome  \
# 0  2007-07-09 00:00:00             NaN  Return to Owner    Neutered Male
# 1  2007-07-09 00:00:00             NaN  Return to Owner    Neutered Male
# 2  2007-07-09 00:00:00             NaN  Return to Owner    Neutered Male
# 3  2004-04-02 00:00:00         Partner         Transfer    Neutered Male
# 4  1997-10-16 00:00:00             NaN  Return to Owner    Neutered Male
#
#       outcome_datetime outcome_weekday  outcome_number animal_id  \
# 0  2017-12-07 14:07:00        Thursday             1.0   A006100
# 1  2014-12-20 16:35:00        Saturday             2.0   A006100
# 2  2014-03-08 17:10:00        Saturday             3.0   A006100
# 3  2014-04-07 15:12:00          Monday             1.0   A047759
# 4  2013-11-16 11:54:00        Saturday             1.0   A134067
#
#                   breed         color intake_condition      intake_type  \
# 0  Spinone Italiano Mix  Yellow/White           Normal            Stray
# 1  Spinone Italiano Mix  Yellow/White           Normal    Public Assist
# 2  Spinone Italiano Mix  Yellow/White           Normal    Public Assist
# 3             Dachshund      Tricolor           Normal  Owner Surrender
# 4     Shetland Sheepdog   Brown/White          Injured    Public Assist
#
#   sex_upon_intake      intake_datetime intake_weekday  intake_number  \
# 0   Neutered Male  2017-12-07 00:00:00       Thursday            1.0
# 1   Neutered Male  2014-12-19 10:21:00         Friday            2.0
# 2   Neutered Male  2014-03-07 14:26:00         Friday            3.0
# 3   Neutered Male  2014-04-02 15:55:00      Wednesday            1.0
# 4   Neutered Male  2013-11-16 09:02:00       Saturday            1.0
#
#              time_in_shelter
# 0  0 days 14:07:00.000000000
# 1  1 days 06:14:00.000000000
# 2  1 days 02:44:00.000000000
# 3  4 days 23:17:00.000000000
# 4  0 days 02:52:00.000000000

# %% [markdown]
# #### Double record of same event: ####
# This dog has once been recorded as a case of 'Owner surrender' and once as 'Public Assist'. Since all the datetime values align, it is safe t say it's a duplicated row.
#
# *I actually found this at the stage of calculating total stay time, however, I'm moving it here to keep the document tidier

# %%
shelter.loc[shelter.duplicated(['animal_id', 'intake_number', 'outcome_number'], keep = False)]
# Out:
#              date_of_birth outcome_subtype outcome_type sex_upon_outcome  \
# 10129  2011-02-17 00:00:00      Aggressive   Euthanasia      Intact Male
# 10130  2011-02-17 00:00:00      Aggressive   Euthanasia      Intact Male
#
#           outcome_datetime outcome_weekday  outcome_number animal_id  \
# 10129  2014-04-17 17:09:00        Thursday             1.0   A672744
# 10130  2014-04-17 17:09:00        Thursday             1.0   A672744
#
#                 breed      color intake_condition      intake_type  \
# 10129  Rottweiler Mix  Black/Tan           Normal    Public Assist
# 10130  Rottweiler Mix  Black/Tan           Normal  Owner Surrender
#
#       sex_upon_intake      intake_datetime intake_weekday  intake_number  \
# 10129     Intact Male  2014-02-17 17:10:00         Monday            1.0
# 10130     Intact Male  2014-02-17 17:10:00         Monday            1.0
#
#                   time_in_shelter
# 10129  58 days 23:59:00.000000000
# 10130  58 days 23:59:00.000000000

# %%
shelter = shelter.drop_duplicates(['animal_id', 'intake_number', 'outcome_number'])

# %% [markdown]
# ### Datatypes: ###
# #### Datetime columns: ####
# Changing their dtype to datetime

# %%
dt_col_regex = r'^date_|_datetime$'

cols_to_dt = shelter.filter(regex = dt_col_regex).columns
for col in cols_to_dt:
    shelter[col] = pd.to_datetime(shelter[col])

# %% [markdown]
# #### Timedelta column: ####
# Redundant data but will be useful for calculations

# %%
shelter['time_in_shelter'] = shelter['outcome_datetime'] - shelter['intake_datetime']

# %% [markdown]
# #### Categorical columns: ####

# %%
categorical_regex = r'_type$|_subtype$|_weekday$|breed$'
categorical_cols = shelter.filter(regex = categorical_regex)

for col in categorical_cols:
    shelter[col] = shelter[col].astype('category')

# %%
shelter.dtypes
# Out:
# date_of_birth        datetime64[ns]
# outcome_subtype            category
# outcome_type               category
# sex_upon_outcome             object
# outcome_datetime     datetime64[ns]
# outcome_weekday            category
# outcome_number              float64
# animal_id                    object
# breed                      category
# color                        object
# intake_condition             object
# intake_type                category
# sex_upon_intake              object
# intake_datetime      datetime64[ns]
# intake_weekday             category
# intake_number               float64
# time_in_shelter     timedelta64[ns]
# dtype: object

# %% [markdown]
# ### Checking for broken rows: ###
# Checking for logical inconsistencies with the dates

# %%
print (shelter.loc[shelter.intake_datetime > shelter.outcome_datetime].shape[0])
print (shelter.loc[shelter.date_of_birth > shelter.intake_datetime].shape[0])
print (shelter.loc[shelter.date_of_birth > shelter.outcome_datetime].shape[0])
# Out:
# 0
# 39
# 2

# %% [markdown]
# <b> Why I decided to keep the intake date as date of birth: </b><br>
# At fist I assumed these were the puppies born in the shelter but after further investigation not all of them were in 'Nursing state' and also there were some, whose date of birth was even later than their outcome date. <u>Date of birth is expected to be a value that is estimated by the shelter staff.</u> so for those cases, I will use intake date as date of birth.

# %%
shelter_time_discrepanies = shelter.loc[(shelter.date_of_birth > shelter.intake_datetime)]
time_discrepanies = shelter_time_discrepanies.apply(lambda x: x.date_of_birth - x.intake_datetime, axis = 1)
time_discrepanies.mean()
# Out:
# Timedelta('9 days 14:22:13.846153846')

# %%
def fix_date_of_birth(row):
    """ 
        Fix rows claiming that the animal was born after
        it was taken in
    """
    if row.date_of_birth > row.intake_datetime: 
        return row.intake_datetime
    return row.date_of_birth

# %%
shelter['fixed_date_of_birth'] = shelter.apply(fix_date_of_birth, axis = 1)

# %%
print (shelter.loc[shelter.fixed_date_of_birth > shelter.intake_datetime].shape[0])
print (shelter.loc[shelter.fixed_date_of_birth > shelter.outcome_datetime].shape[0])
# Out:
# 0
# 0

# %%
shelter['date_of_birth'] = shelter['fixed_date_of_birth']
shelter = shelter.drop('fixed_date_of_birth', axis = 1)

# %% [markdown]
# ### Adding useful columns: ###
# As said, date_of_birth can not be trusted to be precise since the staff most likely made as estimation based on size and behaviour. The dog age will be treated as a categorical feature and will be represented by just the years.

# %%
def get_age(dob, to_time):
    return round((to_time - dob).dt.days / 365.25)

# %%
shelter['age_intake'] = get_age(shelter.date_of_birth, shelter.intake_datetime)
shelter['age_outcome'] = get_age(shelter.date_of_birth, shelter.outcome_datetime)

# %% [markdown]
# ## One row per stay -> one row per dog: ##
# In this dataset, one row represents one shelter stay (PK is compound: animal_id and intake_datetime). A dog can get adopted, then left at the shleter again and so on and each of those stays is recorded as a row. My goal requires a dataset where every row is a unique dog (PK is animal_id). To achieve that I must, for every dog:
# <ol>
#     <li>Take the first intake data - I am interested in when was the first time the dog got in the shelter</li>
#     <li>Take the last outcome data - I am interested in the last outcome - what's the dog's status now.</li>
#     <li>Sum the time in shelter for each stay - This will give me the total shelter time between the first intake and the last outcome <b>without the gaps</b> in between stays</li>
# </ol>
#
# #### Step 1: Separate intakes from outcomes ####
# I separate the dataset into two with only their relevant columns. The 'common' columns like 'date_of_birth' will go to the intakes.

# %%
shelter.loc[shelter.intake_number != shelter.outcome_number]
# Out:
# Empty DataFrame
# Columns: [date_of_birth, outcome_subtype, outcome_type, sex_upon_outcome, outcome_datetime, outcome_weekday, outcome_number, animal_id, breed, color, intake_condition, intake_type, sex_upon_intake, intake_datetime, intake_weekday, intake_number, time_in_shelter, age_intake, age_outcome]
# Index: []

# %%
intakes = shelter[[
    'animal_id', 
    'date_of_birth', 
    'breed',
    'intake_type', 
    'intake_condition', 
    'age_intake',
    'intake_datetime', 
    'intake_weekday',
    'intake_number',
    'color'
    # this column won't make sense anymore
    # 'time_in_shelter'
]].copy()

# %%
outcomes = shelter[[
    'animal_id',
    'outcome_subtype',
    'outcome_type',
    'outcome_datetime',
    'outcome_weekday', 
    'outcome_number',
    'age_outcome']].copy()

# %%
print (intakes.duplicated().sum())
print (outcomes.duplicated().sum())
# Out:
# 0
# 0

# %% [markdown]
# ####  Step 2: Taking last outcome and first intake: ####

# %%
outcomes = outcomes.sort_values('outcome_number')
last_outcomes = outcomes.drop_duplicates('animal_id', keep = 'last')

# %%
intakes = intakes.sort_values('intake_number')
first_intakes = intakes.drop_duplicates('animal_id')

# %% [markdown]
# #### Step 3: Merging first intakes and last outcomes: ####
# This gives me a dataset where each row is a unique dog along with its simplified shelter history.

# %%
dogs = pd.merge(first_intakes, last_outcomes, how = 'inner', on = 'animal_id')

# %% [markdown]
# #### Step 4: Calculating total shelter time: ####
# Back in the shelters dataset, I sum up the shelter time for every dog. That gives me a series with the animal_ids as index and their total shelter time as values. Then I join it with dogs dataset by animal id to get their total shelter stay (without the gaps)

# %%
animals_total_time = shelter.groupby('animal_id')['time_in_shelter'].sum()
animals_total_time.name = 'total_time_in_shelter'

# %%
dogs = pd.merge(dogs, animals_total_time, on = 'animal_id')

# %% [markdown]
# #### Step 5: Remove stay number information: ####
# Just leaving the number of stays for now, not sure if i'll need it

# %%
dogs = dogs.rename(mapper = {'outcome_number': 'stays_count'}, axis = 1)
dogs = dogs.drop('intake_number', axis = 1)

# %% [markdown]
# <hr>

# %% [markdown]
# ## 2. Breeds ##
#
# This is the registered dog breed dataset from the American Kennel Club.

# %%
breeds.head()
# Out:
#          Unnamed: 0                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   277 non-null    object
#  1   description                  277 non-null    object
#  2   temperament                  276 non-null    object
#  3   popularity                   198 non-null    object
#  4   min_height                   277 non-null    float64
#  5   max_height                   277 non-null    float64
#  6   min_weight                   275 non-null    float64
#  7   max_weight                   275 non-null    float64
#  8   min_expectancy               274 non-null    float64
#  9   max_expectancy               274 non-null    float64
#  10  group                        277 non-null    object
#  11  grooming_frequency_value     270 non-null    float64
#  12  grooming_frequency_category  270 non-null    object
#  13  shedding_value               257 non-null    float64
#  14  shedding_category            257 non-null    object
#  15  energy_level_value           271 non-null    float64
#  16  energy_level_category        271 non-null    object
#  17  trainability_value           253 non-null    float64
#  18  trainability_category        253 non-null    object
#  19  demeanor_value               252 non-null    float64
#  20  demeanor_category            252 non-null    object
# dtypes: float64(11), object(10)
# memory usage: 45.6+ KB

# %% [markdown]
# #### Column names and data types: ####

# %%
breeds = breeds.rename(mapper = {'Unnamed: 0': 'breed'}, axis = 1)

# %%
cat_col_regex = r'_category|group$'

cat_cols = breeds.filter(regex = cat_col_regex).columns
for col in cat_cols:
    breeds[col] = breeds[col].astype('category')

# %%
breeds.dtypes
# Out:
# breed                            object
# description                      object
# temperament                      object
# popularity                       object
# min_height                      float64
# max_height                      float64
# min_weight                      float64
# max_weight                      float64
# min_expectancy                  float64
# max_expectancy                  float64
# group                          category
# grooming_frequency_value        float64
# grooming_frequency_category    category
# shedding_value                  float64
# shedding_category              category
# energy_level_value              float64
# energy_level_category          category
# trainability_value              float64
# trainability_category          category
# demeanor_value                  float64
# demeanor_category              category
# dtype: object

# %% [markdown]
# #### Checking for duplicates: ####

# %%
print (breeds.duplicated().sum())
print (breeds.duplicated('breed').sum())
# Out:
# 0
# 0

# %% [markdown]
# ## 3. Merge 'dogs' and 'breeds'. (Attempt no. 1) ##
# I want to join the two datasets, however, most of the strays are not pure breeds and that causes a few difficulties.
# <uol>
#     <li>I don't want to lose breed information</li>
#     <li>Keeping all breeds conflicts with my one-dog-per-row plan</li>
# </uol>
#
# In this part I explore what I am dealing with and what my options are.

# %%
# making sure the absence of this value means no match from breeds dataset
breeds['description'].isna().sum()
# Out:
# 0

# %%
test_merge = pd.merge(dogs, breeds, how = 'left', on = 'breed')
unmatched_breeds = test_merge.loc[test_merge['description'].isna(), 'breed'].value_counts().to_dict().keys()
breed_mixes_num = [len(breed.split('/')) for breed in unmatched_breeds]
set(breed_mixes_num)
# Out:
# {1, 2, 3}

# %% [markdown]
# The only 'three breed' instances are the ones in which the color is added as part of the breed name. Removing that it will be safe to assume that every mix (or at least the information we have for it) is of max of 2 breeds. <b> One dog can be a mix of max 2 breeds. </b>

# %%
three_breeds = [breed for breed in unmatched_breeds if len(breed.split('/')) > 2]
three_breeds
# Out:
# ['Labrador Retriever/Black/Tan Hound',
#  'German Shepherd/Black/Tan Hound',
#  'Black/Tan Hound/Labrador Retriever',
#  'Black/Tan Hound/Black Mouth Cur',
#  'Black/Tan Hound/Siberian Husky',
#  'Black/Tan Hound/German Shepherd',
#  'Plott Hound/Black/Tan Hound',
#  'Black/Tan Hound/Beagle',
#  'Black/Tan Hound/Great Dane',
#  'Doberman Pinsch/Black/Tan Hound',
#  'Basset Hound/Black/Tan Hound']

# %%
breeds.loc[breeds.breed.str.lower().str.contains('black')]
# Out:
#                       breed  \
# 39  Black and Tan Coonhound
# 40    Black Russian Terrier
#
#                                           description  \
# 39  Black and Tans have an amazingly sensitive nos...
# 40  What’s the word we’re looking for? Imposing? M...
#
#                     temperament popularity  min_height  max_height  \
# 39    Easy-Going, Bright, Brave        138       58.42       68.58
# 40  Intelligent, Calm, Powerful        118       66.04       76.20
#
#     min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 39   29.483504   49.895161            10.0            12.0  ...
# 40   36.287390   58.967008            10.0            12.0  ...
#
#    grooming_frequency_value  grooming_frequency_category shedding_value  \
# 39                      0.4              Weekly Brushing            0.6
# 40                      0.8               Daily Brushing            0.6
#
#     shedding_category energy_level_value  energy_level_category  \
# 39           Seasonal                0.6       Regular Exercise
# 40           Seasonal                0.8              Energetic
#
#    trainability_value  trainability_category demeanor_value  \
# 39                0.4            Independent            0.8
# 40                0.8          Easy Training            0.4
#
#           demeanor_category
# 39                 Friendly
# 40  Reserved with Strangers
#
# [2 rows x 21 columns]

# %% [markdown]
# Black/Tan Hound becomes Black and Tan Coohhound:

# %%
dogs['breed'] = dogs['breed'].apply(lambda breed: re.sub('Black/Tan Hound', 'Black and Tan Coonhound', breed))

# %% [markdown]
# ## 4. Dealing with breed mixes by mixing breeds: ##
# Stray dogs are not expected to be of a pure breed. The values in the breed column often contain the word 'Mix' or have 1 or 2 breeds mentioned. I assume the breeds are given by the staff based off of an estimation of appearance, weight, demeanor etc. In order to account for the 'mixes' I will try to 'mix' the breeds in the dataset as well - try to 'derive' the mixed breed out of the main ones by averaging values. Before I 'mix', however, I must:
# <ol>
#     <li>Explode the breed column. This will give me one row for every breed that a dog has traits of. (PK is animal_id and breed)</li>
#     <li>Merge with breeds</li>
#     <li>Take care of unmatched breeds</li>
# </ol>

# %% [markdown]
# ### Preparation for merge: ###
#
# The word 'Mix' carries information, however, not information that I can do anything with at the moment. I assume the value will be more useful without it because it can be matched to a breed.

# %%
dogs['breed'] = dogs['breed'].apply(lambda breed: re.sub('Mix', '', breed))

# %% [markdown]
# #### Step 1: Explode breed column: ####
# For the sake of a smooth merge, I will need a row for every breed that a dog has 'mixed in'. That means that one animal_id will appear twice if it is a mix between two breeds.

# %%
dogs_mixes = dogs.copy()
dogs_mixes['breed'] = dogs_mixes['breed'].str.split('/')
dogs_mixes.shape
# Out:
# (38909, 17)

# %%
dogs_mixes = dogs_mixes.explode(column = 'breed')

# %%
dogs_mixes.sort_values('animal_id').head()
# Out:
#       animal_id date_of_birth               breed      intake_type  \
# 0       A006100    2007-07-09   Spinone Italiano             Stray
# 28010   A047759    2004-04-02           Dachshund  Owner Surrender
# 28011   A134067    1997-10-16   Shetland Sheepdog    Public Assist
# 28012   A141142    1998-06-01  Labrador Retriever            Stray
# 28012   A141142    1998-06-01            Pit Bull            Stray
#
#       intake_condition  age_intake     intake_datetime intake_weekday  \
# 0               Normal        10.0 2017-12-07 00:00:00       Thursday
# 28010           Normal        10.0 2014-04-02 15:55:00      Wednesday
# 28011          Injured        16.0 2013-11-16 09:02:00       Saturday
# 28012             Aged        15.0 2013-11-16 14:46:00       Saturday
# 28012             Aged        15.0 2013-11-16 14:46:00       Saturday
#
#               color time_in_shelter outcome_subtype     outcome_type  \
# 0      Yellow/White 0 days 14:07:00             NaN  Return to Owner
# 28010      Tricolor 4 days 23:17:00         Partner         Transfer
# 28011   Brown/White 0 days 02:52:00             NaN  Return to Owner
# 28012   Black/White 0 days 20:54:00             NaN  Return to Owner
# 28012   Black/White 0 days 20:54:00             NaN  Return to Owner
#
#          outcome_datetime outcome_weekday  stays_count  age_outcome  \
# 0     2014-03-08 17:10:00        Saturday          3.0          7.0
# 28010 2014-04-07 15:12:00          Monday          1.0         10.0
# 28011 2013-11-16 11:54:00        Saturday          1.0         16.0
# 28012 2013-11-17 11:40:00          Sunday          1.0         15.0
# 28012 2013-11-17 11:40:00          Sunday          1.0         15.0
#
#       total_time_in_shelter
# 0           2 days 23:05:00
# 28010       4 days 23:17:00
# 28011       0 days 02:52:00
# 28012       0 days 20:54:00
# 28012       0 days 20:54:00

# %%
dogs_mixes['breed'] = dogs_mixes['breed'].apply(lambda br: br.strip().replace('St.', 'Saint'))

# %% [markdown]
# #### Step 2: Merge and add 'has_match' column: ####
# I want to know which rows need their breed 'fixed' in order to smoothly merge with 'breeds' dataframe. <br>
# So I merge with only the breed column and use description column as flag - if empty -> breed is not matched. (After checking that all breeds have description)

# %%
dogs_mixes = pd.merge(dogs_mixes, breeds[['breed', 'description']], how = 'left', on = 'breed')

# %% [markdown]
# step 2: Rename column and convert values to boolean

# %%
dogs_mixes['description'] = dogs_mixes['description'].apply(lambda x: not pd.isnull(x))

# %%
dogs_mixes = dogs_mixes.rename({'description': 'has_match'}, axis = 1)

# %%
dogs_mixes.has_match.dtype
# Out:
# dtype('bool')

# %%
dogs_mixes.loc[dogs_mixes['breed'] == 'Pit Bull'].head(2)
# Out:
#    animal_id date_of_birth     breed intake_type intake_condition  age_intake  \
# 6    A726448    2004-05-11  Pit Bull       Stray             Sick        12.0
# 12   A726455    2015-06-11  Pit Bull       Stray           Normal         1.0
#
#        intake_datetime intake_weekday       color  time_in_shelter  \
# 6  2016-05-11 08:20:00      Wednesday       Brown 15 days 07:27:00
# 12 2016-05-11 09:19:00      Wednesday  Blue/White 34 days 00:11:00
#
#    outcome_subtype outcome_type    outcome_datetime outcome_weekday  \
# 6          Partner     Transfer 2016-05-26 15:47:00        Thursday
# 12          Foster     Adoption 2016-06-14 09:30:00         Tuesday
#
#     stays_count  age_outcome total_time_in_shelter  has_match
# 6           1.0         12.0      15 days 07:27:00      False
# 12          1.0          1.0      34 days 00:11:00      False

# %% [markdown]
# #### Step 3: Take care of unmatched breeds ####
#
# At first I tried to map the unmatched ones to the AKC breeds by hand and I noticed a pattern - if the breed existed in the AKC dataset, usually <b>the stem of at least one word on the unmatched breed would be the same as the stem of some word in the official version.</b>. (e.g.  'Mini Poodle' => 'Poodle (Miniature)' or 'Cavalier Span' -> 'Cavalier King Charles Spaniel') So with some *restrictions, I managed to automate the process with very good results. <br><br>
# For an unmatched breed, I separate it into words (after lowering, strip, removing punctuation etc) and try to match it to each word in the official breeds. At the end, I have a dataset ('breed' , 'score'), which keeps score of how many words have been matched.<br>
# Out of that dataset, the breeds with max score are put in a list and mapped to the unmatched name: <br><br>
# <code> shelter_to_akc_breeds = { 'Collie Smooth': ['Bearded Collie', 'Border Collie', 'Collie', 'Smooth Fox Terrier'], ...} </code><br><br>
# This dictionary is later used to fill in the missing breeds, using random where there are more than one.<br/><br>
# *restrictions mentioned - I only match from the start (see is_word_in_breed()) to avoid "meaningless" matches like '<b>Pit</b> Bull</b>' and 'Chinese S<b>pit</b>s'. I also have an array of THROW OFFS for the same reason - avoiding words that won't help the matching process. For comparison:
# <uol>
# <li>'shorthair' - is not so descriptive of the breed as it is of the fur. Causs matches with breeds with all kinds of characteristics.</li>
# <li>'hound' - may lead to a match that's not exactly the same type of hound but it still narrows down to a subset with similar characteristics</li>
# </uol>

# %%
reg_breeds = breeds.breed
THROW_OFFS = ['longhair', 'shorthair', 'english']

# %%
def normalize_str(str):
    return re.sub(r'[-()]', '', str.lower()).strip()

# %%
def is_word_in_breed(breed, word):
    """ 
        Matches "word" to the beginning of
        every word in "row.breed"
        pit -x-> spits
        span --> spaniel
    """
    breed = normalize_str(breed)
    match_from_start = r'^' + word + '| ' + word
    to_add = 1 if re.search(match_from_start, breed) else 0
    return to_add

# %%
def get_match_score_of_row(row, word):
    return row['score'] + is_word_in_breed(row.breed, word)

# %%
def best_breed_matches(breed):
    """
        Returns a list of AKC registered breeds that best match 'breed'
    """
    breed_words = [normalize_str(word) for word in breed.split()]
    
    breed_match = breeds[['breed']].copy()
    breed_match['score'] = 0;
    
    for word in breed_words:
        if word in THROW_OFFS:
            continue
        breed_match['score'] = breed_match.apply(lambda row: get_match_score_of_row(row, word), axis = 1)
        
    top_matches =  breed_match.loc[breed_match['score'] == breed_match['score'].max()].reset_index()
    return top_matches['breed'].tolist() if (top_matches['score'].max() > 0) else []

# %% [markdown]
# Creating a dictionary for breed mapping from the unofficial unmatched breeds to the AKC registered breeds.

# %%
unmatched_breeds = dogs_mixes.loc[~dogs_mixes['has_match'], 'breed'].unique()

# %%
shelter_to_akc_breeds = {}

for unmatched_breed in unmatched_breeds:
    shelter_to_akc_breeds[unmatched_breed] = best_breed_matches(unmatched_breed)

shelter_to_akc_breeds
# Out:
# {'Chihuahua Shorthair': ['Chihuahua'],
#  'Queensland Heeler': ['Lancashire Heeler'],
#  'Pit Bull': ['American Bulldog',
#   'Bull Terrier',
#   'Bulldog',
#   'Bullmastiff',
#   'French Bulldog',
#   'Miniature Bull Terrier',
#   'Staffordshire Bull Terrier'],
#  'Catahoula': ['Catahoula Leopard Dog'],
#  'Mexican Hairless': ['American Hairless Terrier'],
#  'German Shorthair Pointer': ['German Longhaired Pointer',
#   'German Shorthaired Pointer',
#   'German Wirehaired Pointer'],
#  'Anatol Shepherd': ['Anatolian Shepherd Dog'],
#  'Wire Hair Fox Terrier': ['Wire Fox Terrier'],
#  'German Shepherd': ['German Shepherd Dog'],
#  'Chihuahua Longhair': ['Chihuahua'],
#  'Staffordshire': ['American Staffordshire Terrier',
#   'Staffordshire Bull Terrier'],
#  'Black Mouth Cur': ['Black and Tan Coonhound',
#   'Black Russian Terrier',
#   'Curly-Coated Retriever',
#   'Mountain Cur'],
#  'Jack Russell Terrier': ['Parson Russell Terrier', 'Russell Terrier'],
#  'Blue Lacy': ['Bluetick Coonhound', 'Kerry Blue Terrier'],
#  'Miniature Poodle': ['Poodle (Miniature)'],
#  'Flat Coat Retriever': ['Flat-Coated Retriever'],
#  'American Pit Bull Terrier': ['American Bulldog',
#   'American Hairless Terrier',
#   'American Staffordshire Terrier',
#   'Bull Terrier',
#   'Miniature Bull Terrier',
#   'Staffordshire Bull Terrier'],
#  'Dachshund Longhair': ['Dachshund'],
#  'Chinese Sharpei': ['Chinese Shar-Pei'],
#  'Dachshund Wirehair': ['Dachshund',
#   'German Wirehaired Pointer',
#   'Slovakian Wirehaired Pointer',
#   'Wirehaired Pointing Griffon',
#   'Wirehaired Vizsla'],
#  'Doberman Pinsch': ['Doberman Pinscher'],
#  'Rhod Ridgeback': ['Rhodesian Ridgeback'],
#  'Toy Poodle': ['Poodle (Toy)'],
#  'Boykin Span': ['Boykin Spaniel'],
#  'West Highland': ['West Highland White Terrier'],
#  'Feist': [],
#  'Alaskan Husky': ['Alaskan Malamute', 'Siberian Husky'],
#  'Bruss Griffon': ['Brussels Griffon'],
#  'Old English Bulldog': ['American Bulldog',
#   'Bulldog',
#   'French Bulldog',
#   'Old English Sheepdog'],
#  'English Bulldog': ['American Bulldog', 'Bulldog', 'French Bulldog'],
#  'Schnauzer Giant': ['Giant Schnauzer'],
#  'Bull Terrier Miniature': ['Miniature Bull Terrier'],
#  'Standard Poodle': ['Poodle (Standard)'],
#  'American Eskimo': ['American Eskimo Dog'],
#  'Collie Smooth': ['Bearded Collie',
#   'Border Collie',
#   'Collie',
#   'Smooth Fox Terrier'],
#  'Redbone Hound': ['Afghan Hound',
#   'American Leopard Hound',
#   'Basset Hound',
#   'Bavarian Mountain Scent Hound',
#   'Ibizan Hound',
#   'Pharaoh Hound',
#   'Plott Hound',
#   'Redbone Coonhound',
#   'Transylvanian Hound'],
#  'Glen Of Imaal': ['Glen of Imaal Terrier'],
#  'English Coonhound': ['American English Coonhound',
#   'Black and Tan Coonhound',
#   'Bluetick Coonhound',
#   'Redbone Coonhound',
#   'Treeing Walker Coonhound'],
#  'Cavalier Span': ['Cavalier King Charles Spaniel'],
#  'Manchester Terrier': ['Manchester Terrier (Standard)',
#   'Manchester Terrier (Toy)'],
#  'Presa Canario': ['Perro de Presa Canario'],
#  'Saint Bernard Smooth Coat': ['Saint Bernard'],
#  'Akbash': [],
#  'Bluetick Hound': ['Afghan Hound',
#   'American Leopard Hound',
#   'Basset Hound',
#   'Bavarian Mountain Scent Hound',
#   'Bluetick Coonhound',
#   'Ibizan Hound',
#   'Pharaoh Hound',
#   'Plott Hound',
#   'Transylvanian Hound'],
#  'Coton De Tulear': ['Coton de Tulear'],
#  'Treeing Cur': ['Curly-Coated Retriever',
#   'Mountain Cur',
#   'Treeing Tennessee Brindle',
#   'Treeing Walker Coonhound'],
#  'Picardy Sheepdog': ['Belgian Sheepdog',
#   'Bergamasco Sheepdog',
#   'Croatian Sheepdog',
#   'Icelandic Sheepdog',
#   'Old English Sheepdog',
#   'Polish Lowland Sheepdog',
#   'Portuguese Sheepdog',
#   'Shetland Sheepdog'],
#  'Saint Bernard Rough Coat': ['Saint Bernard'],
#  'Sussex Span': ['Sussex Spaniel'],
#  'Pbgv': [],
#  'Collie Rough': ['Bearded Collie', 'Border Collie', 'Collie'],
#  'English Shepherd': ['Anatolian Shepherd Dog',
#   'Australian Shepherd',
#   'Bohemian Shepherd',
#   'Caucasian Shepherd Dog',
#   'Central Asian Shepherd Dog',
#   'Dutch Shepherd',
#   'German Shepherd Dog',
#   'Miniature American Shepherd',
#   'Pyrenean Shepherd',
#   'Romanian Mioritic Shepherd Dog'],
#  'Chesa Bay Retr': ['Chesapeake Bay Retriever'],
#  'Dogue De Bordeaux': ['Dogue de Bordeaux'],
#  'Patterdale Terr': ['Airedale Terrier',
#   'American Hairless Terrier',
#   'American Staffordshire Terrier',
#   'Australian Terrier',
#   'Bedlington Terrier',
#   'Biewer Terrier',
#   'Black Russian Terrier',
#   'Border Terrier',
#   'Boston Terrier',
#   'Bull Terrier',
#   'Cairn Terrier',
#   'Cesky Terrier',
#   'Dandie Dinmont Terrier',
#   'Glen of Imaal Terrier',
#   'Irish Terrier',
#   'Kerry Blue Terrier',
#   'Lakeland Terrier',
#   'Manchester Terrier (Standard)',
#   'Manchester Terrier (Toy)',
#   'Miniature Bull Terrier',
#   'Norfolk Terrier',
#   'Norwich Terrier',
#   'Parson Russell Terrier',
#   'Rat Terrier',
#   'Russell Terrier',
#   'Scottish Terrier',
#   'Sealyham Terrier',
#   'Silky Terrier',
#   'Skye Terrier',
#   'Smooth Fox Terrier',
#   'Soft Coated Wheaten Terrier',
#   'Staffordshire Bull Terrier',
#   'Teddy Roosevelt Terrier',
#   'Tibetan Terrier',
#   'Toy Fox Terrier',
#   'Welsh Terrier',
#   'West Highland White Terrier',
#   'Wire Fox Terrier',
#   'Yorkshire Terrier'],
#  'English Pointer': ['German Longhaired Pointer',
#   'German Shorthaired Pointer',
#   'German Wirehaired Pointer',
#   'Pointer',
#   'Portuguese Pointer',
#   'Slovakian Wirehaired Pointer',
#   'Small Munsterlander Pointer'],
#  'Lowchen': [],
#  'Unknown': [],
#  'Podengo Pequeno': ['Portuguese Podengo Pequeno'],
#  'Treeing Tennesse Brindle': ['Treeing Tennessee Brindle'],
#  'Landseer': [],
#  'Dandie Dinmont': ['Dandie Dinmont Terrier'],
#  'Grand Basset Griffon Vendeen': ['Grand Basset Griffon Vendéen'],
#  'Bouv Flandres': ['Bouvier des Flandres'],
#  'Cirneco': ['Cirneco dell’Etna'],
#  'Swiss Hound': ['Afghan Hound',
#   'American Leopard Hound',
#   'Basset Hound',
#   'Bavarian Mountain Scent Hound',
#   'Greater Swiss Mountain Dog',
#   'Ibizan Hound',
#   'Pharaoh Hound',
#   'Plott Hound',
#   'Transylvanian Hound'],
#  'Yorkshire': ['Yorkshire Terrier'],
#  'Kangal': [],
#  'Dachshund Stan': ['Dachshund',
#   'Manchester Terrier (Standard)',
#   'Poodle (Standard)',
#   'Standard Schnauzer'],
#  'Entlebucher': ['Entlebucher Mountain Dog'],
#  'Eng Toy Spaniel': ['English Toy Spaniel'],
#  'Bedlington Terr': ['Bedlington Terrier'],
#  'Port Water Dog': ['Portuguese Water Dog'],
#  'Sealyham Terr': ['Sealyham Terrier']}

# %% [markdown]
# #### Filling in the missing values: ####

# %%
def match_dog_breed(row, breed_dict = shelter_to_akc_breeds):
    """ 
        Used to fill in missing breed_match values
    """
    dog_misses_breed = not row.has_match
    if dog_misses_breed:
        possible_breeds = breed_dict[row.breed]
        if not len(possible_breeds): return None
        return possible_breeds[random.randint(0, len(possible_breeds) - 1)]
    return row.breed_match if hasattr(row, 'breed_match') else row.breed

# %%
dogs_mixes['breed_match'] = dogs_mixes.apply(match_dog_breed, axis = 1)

# %%
# Updating has_match
dogs_mixes['has_match'] = dogs_mixes.apply(lambda row: not pd.isnull(row.breed_match), axis = 1)
dogs_mixes.head(5)
# Out:
#   animal_id date_of_birth                breed      intake_type  \
# 0   A006100    2007-07-09     Spinone Italiano            Stray
# 1   A726434    2009-05-10  Chihuahua Shorthair            Stray
# 2   A726435    2013-05-10            Dachshund  Owner Surrender
# 3   A726442    2015-12-11    Queensland Heeler            Stray
# 4   A726442    2015-12-11            Dachshund            Stray
#
#   intake_condition  age_intake     intake_datetime intake_weekday  \
# 0           Normal        10.0 2017-12-07 00:00:00       Thursday
# 1           Normal         7.0 2016-05-10 18:08:00        Tuesday
# 2           Normal         3.0 2016-05-21 18:08:00       Saturday
# 3           Normal         0.0 2016-05-10 18:55:00        Tuesday
# 4           Normal         0.0 2016-05-10 18:55:00        Tuesday
#
#           color   time_in_shelter outcome_subtype     outcome_type  \
# 0  Yellow/White   0 days 14:07:00             NaN  Return to Owner
# 1   Black/White  11 days 19:13:00             NaN         Adoption
# 2   Black/White 128 days 14:51:00             NaN         Adoption
# 3     Tan/White   3 days 23:05:00             NaN         Adoption
# 4     Tan/White   3 days 23:05:00             NaN         Adoption
#
#      outcome_datetime outcome_weekday  stays_count  age_outcome  \
# 0 2014-03-08 17:10:00        Saturday          3.0          7.0
# 1 2016-05-22 13:21:00          Sunday          1.0          7.0
# 2 2016-05-17 17:56:00         Tuesday          2.0          3.0
# 3 2016-05-14 18:00:00        Saturday          1.0          0.0
# 4 2016-05-14 18:00:00        Saturday          1.0          0.0
#
#   total_time_in_shelter  has_match        breed_match
# 0       2 days 23:05:00       True   Spinone Italiano
# 1      11 days 19:13:00       True          Chihuahua
# 2     135 days 14:39:00       True          Dachshund
# 3       3 days 23:05:00       True  Lancashire Heeler
# 4       3 days 23:05:00       True          Dachshund

# %% [markdown]
# #### A few more missing values ####
#
# Breeds the mapper failed to recognize because they are aliases. And a few unknowns. I manually created a dictionary for them.

# %%
dogs_mixes.loc[dogs_mixes['breed_match'].isnull()]['breed'].value_counts()
# Out:
# Pbgv        28
# Feist       16
# Landseer    10
# Lowchen      3
# Akbash       2
# Unknown      2
# Kangal       1
# Name: breed, dtype: int64

# %%
# Dropping 'Unknown' breeds
dogs_mixes = dogs_mixes.loc[dogs_mixes['breed'] != 'Unknown'].copy()

# %%
manual_breed_match = {
    'Pbgv': ['Petit Basset Griffon Vendéen'],
    'Feist': ['Rat Terrier'],
    'Landseer': ['Newfoundland'],
    'Lowchen': ['Löwchen'],
    'Akbash': ['Anatolian Shepherd Dog'],
    'Kangal': ['Anatolian Shepherd Dog']
}

# %%
# Matching dog breeds with manual map this time
dogs_mixes['breed_match'] = dogs_mixes.apply(lambda row: match_dog_breed(row, manual_breed_match), axis = 1)

# %%
# Updating has_match
dogs_mixes['has_match'] = dogs_mixes.apply(lambda row: not pd.isnull(row.breed_match), axis = 1)

# %%
dogs_mixes[dogs_mixes.has_match == False].shape[0]
# Out:
# 0

# %% [markdown]
# ### Mixing breeds - getting one dog per row: ###
#
# Every row now corresponds to exactly one breed from the 'breeds' dataset. My next goal is for one row to represent one unique dog with all the information from 'shelter' and 'breeds'. The question is, how will a dog of mixed breed be mapped to a dataset of pure breeds?
#
# <ol>
#     <li>Merge with breeds while there's still one breed per row</li>
#     <li>
#         Pivot breed columns
#     </li>
#     <li>
#         "Mix" breeds:<br>
#             - Numrical features - take the mean of the two breeds<br/>
#             - Categorical features - if they differ, put in 'Miscellaneous Class'<br/>
#             - * Description - keeping both columns for now<br/>
#             - * Temperament - taking the set of all characteristics mentioned for both breeds<br/>
#     </li>
#     <li>Discard useless columns</li>
# </ol>
#
# #### Step 1: Merge with breeds: ####

# %%
dogs_mixes['breed_num'] = dogs_mixes.groupby('animal_id').cumcount()

# %%
dogs_breeds = pd.merge(dogs_mixes, breeds, how = 'left', left_on = 'breed_match', right_on = 'breed')
dogs_breeds
# Out:
#       animal_id date_of_birth              breed_x      intake_type  \
# 0       A006100    2007-07-09     Spinone Italiano            Stray
# 1       A726434    2009-05-10  Chihuahua Shorthair            Stray
# 2       A726435    2013-05-10            Dachshund  Owner Surrender
# 3       A726442    2015-12-11    Queensland Heeler            Stray
# 4       A726442    2015-12-11            Dachshund            Stray
# ...         ...           ...                  ...              ...
# 45070   A689001    2012-09-27             Pit Bull            Stray
# 45071   A686173    2014-07-24    Australian Kelpie            Stray
# 45072   A685886    2012-08-14             Pit Bull            Stray
# 45073   A688161    2013-11-15             Pit Bull            Stray
# 45074   A688284    2011-09-17             Pit Bull            Stray
#
#       intake_condition  age_intake     intake_datetime intake_weekday  \
# 0               Normal        10.0 2017-12-07 00:00:00       Thursday
# 1               Normal         7.0 2016-05-10 18:08:00        Tuesday
# 2               Normal         3.0 2016-05-21 18:08:00       Saturday
# 3               Normal         0.0 2016-05-10 18:55:00        Tuesday
# 4               Normal         0.0 2016-05-10 18:55:00        Tuesday
# ...                ...         ...                 ...            ...
# 45070           Normal         2.0 2014-09-27 16:27:00       Saturday
# 45071          Nursing         0.0 2014-08-18 08:57:00         Monday
# 45072           Normal         2.0 2014-08-14 10:54:00       Thursday
# 45073           Normal         1.0 2014-09-15 13:54:00         Monday
# 45074           Normal         3.0 2014-09-17 13:14:00      Wednesday
#
#                      color   time_in_shelter  ... grooming_frequency_value  \
# 0             Yellow/White   0 days 14:07:00  ...                      0.4
# 1              Black/White  11 days 19:13:00  ...                      0.2
# 2              Black/White 128 days 14:51:00  ...                      0.4
# 3                Tan/White   3 days 23:05:00  ...                      0.2
# 4                Tan/White   3 days 23:05:00  ...                      0.4
# ...                    ...               ...  ...                      ...
# 45070          White/Brown  69 days 00:47:00  ...                      0.2
# 45071          Black/White   2 days 05:09:00  ...                      0.4
# 45072           Blue/White   6 days 01:07:00  ...                      0.2
# 45073           Blue/White   8 days 00:31:00  ...                      0.4
# 45074  Brown Brindle/White   2 days 23:11:00  ...                      0.4
#
#       grooming_frequency_category shedding_value shedding_category  \
# 0                 Weekly Brushing            NaN               NaN
# 1           Occasional Bath/Brush            0.4        Occasional
# 2                 Weekly Brushing            0.4        Occasional
# 3           Occasional Bath/Brush            0.6          Seasonal
# 4                 Weekly Brushing            0.4        Occasional
# ...                           ...            ...               ...
# 45070       Occasional Bath/Brush            0.6          Seasonal
# 45071             Weekly Brushing            0.8         Regularly
# 45072       Occasional Bath/Brush            0.6          Seasonal
# 45073             Weekly Brushing            0.4        Occasional
# 45074             Weekly Brushing            0.4        Occasional
#
#        energy_level_value  energy_level_category trainability_value  \
# 0                     0.8              Energetic                0.6
# 1                     0.6       Regular Exercise                0.4
# 2                     0.6       Regular Exercise                0.6
# 3                     0.8              Energetic                0.8
# 4                     0.6       Regular Exercise                0.6
# ...                   ...                    ...                ...
# 45070                 0.8              Energetic                0.6
# 45071                 0.8              Energetic                1.0
# 45072                 0.8              Energetic                0.6
# 45073                 0.8              Energetic                0.2
# 45074                 0.8              Energetic                0.2
#
#        trainability_category demeanor_value  demeanor_category
# 0                  Agreeable            0.6   Alert/Responsive
# 1                Independent            0.6   Alert/Responsive
# 2                  Agreeable            0.6   Alert/Responsive
# 3              Easy Training            0.8           Friendly
# 4                  Agreeable            0.6   Alert/Responsive
# ...                      ...            ...                ...
# 45070              Agreeable            0.6   Alert/Responsive
# 45071        Eager to Please            0.6   Alert/Responsive
# 45072              Agreeable            0.6   Alert/Responsive
# 45073        May be Stubborn            0.8           Friendly
# 45074        May be Stubborn            0.8           Friendly
#
# [45075 rows x 41 columns]

# %%
dogs_breeds.dtypes.keys()
# Out:
# Index(['animal_id', 'date_of_birth', 'breed_x', 'intake_type',
#        'intake_condition', 'age_intake', 'intake_datetime', 'intake_weekday',
#        'color', 'time_in_shelter', 'outcome_subtype', 'outcome_type',
#        'outcome_datetime', 'outcome_weekday', 'stays_count', 'age_outcome',
#        'total_time_in_shelter', 'has_match', 'breed_match', 'breed_num',
#        'breed_y', 'description', 'temperament', 'popularity', 'min_height',
#        'max_height', 'min_weight', 'max_weight', 'min_expectancy',
#        'max_expectancy', 'group', 'grooming_frequency_value',
#        'grooming_frequency_category', 'shedding_value', 'shedding_category',
#        'energy_level_value', 'energy_level_category', 'trainability_value',
#        'trainability_category', 'demeanor_value', 'demeanor_category'],
#       dtype='object')

# %% [markdown]
# #### Mid-step: dropping and renaming columns

# %%
dogs_breeds = dogs_breeds.rename({'breed_x': 'breed'}, axis = 1)

# %%
def average_row_vals():
    dogs_breeds['avg_height'] = dogs_breeds[['min_height', 'min_height']].mean(axis=1)
    dogs_breeds['avg_weight'] = dogs_breeds[['min_weight', 'max_weight']].mean(axis=1)
    dogs_breeds['avg_expectancy'] = dogs_breeds[['min_expectancy', 'max_expectancy']].mean(axis=1)

# %%
average_row_vals()

# %%
more_useless_cols_re = [r'_category$', 'popularity', r'_y$', r'^min_|max_']
cols_to_remove = []
for regex in more_useless_cols_re:
    cols_to_remove += dogs_breeds.filter(regex = regex).columns.tolist()

dogs_breeds = dogs_breeds.drop(cols_to_remove, axis = 1)

# %% [markdown]
# #### Step 2: Pivot breed columns ####

# %%
pivoted = dogs_breeds.pivot(
    index='animal_id', 
    columns='breed_num', 
    values=[
    'breed_match', 
    'breed', 
    'description', 
    'group', 
    'temperament', 
    'avg_height',
    'avg_weight',
    'avg_expectancy',
    'grooming_frequency_value',
    'shedding_value',
    'energy_level_value',
    'trainability_value',
    'demeanor_value'
    ]).reset_index()

# %% [markdown]
# #### Step 3: "Mix" breeds ####
# Taking the mean of all numerical columns:

# %%
numerical_cols= [
    'avg_height',
    'avg_weight',
    'avg_expectancy',
    'grooming_frequency_value',
    'shedding_value',
    'energy_level_value',
    'trainability_value',
    'demeanor_value']

# %%
for col in numerical_cols:
    pivoted[col + '_final'] =  pivoted[col].mean(axis = 1)

# %%
cols = [col + (('_' + str(num))if str(num) else '') for col, num in pivoted.columns]

# %%
pivoted.columns = cols

# %%
more_useless_cols_re = [r'_value_[0-9]$', '^avg_.*_[0-9]$']
cols_to_remove = []
for regex in more_useless_cols_re:
    cols_to_remove += pivoted.filter(regex = regex).columns.tolist()

pivoted = pivoted.drop(cols_to_remove, axis = 1)

# %% [markdown]
# ### Fixing categorical and string cols: ####

# %% [markdown]
# #### Fix temperament: ####
# Temperament is usually a string of three traits separated by a column. For the "mix" I take the set of those traits.

# %%
def join_vals(temperaments):
    str1 = temperaments['temperament_0']
    str2 = temperaments['temperament_1']
    str1 = str1 if not pd.isnull(str1) else ''
    str2 = str2 if not pd.isnull(str2) else ''
    return str1 + (', ' + str2 if str2 else '')

# %%
pivoted['temperament'] = pivoted[['temperament_0', 'temperament_1']].agg(join_vals, axis = 1).str.lower()

# %%
pivoted = pivoted.drop(['temperament_0', 'temperament_1'], axis = 1)

# %%
pivoted.head(3)
# Out:
#   animal_id      breed_match_0 breed_match_1            breed_0 breed_1  \
# 0   A006100   Spinone Italiano           NaN   Spinone Italiano     NaN
# 1   A047759          Dachshund           NaN          Dachshund     NaN
# 2   A134067  Shetland Sheepdog           NaN  Shetland Sheepdog     NaN
#
#                                        description_0 description_1  \
# 0  The Spinone Italiano (plural: Spinoni Italiani...           NaN
# 1  The word “icon” is terribly overworked, but th...           NaN
# 2  The Shetland Sheepdog is a small, active, and ...           NaN
#
#           group_0 group_1  avg_height_final  avg_weight_final  \
# 0  Sporting Group     NaN             55.88               NaN
# 1     Hound Group     NaN             12.70          9.752236
# 2   Herding Group     NaN             33.02          9.071847
#
#    avg_expectancy_final  grooming_frequency_value_final  shedding_value_final  \
# 0                  11.0                             0.4                   NaN
# 1                  14.0                             0.4                   0.4
# 2                  13.0                             0.6                   0.6
#
#    energy_level_value_final  trainability_value_final  demeanor_value_final  \
# 0                       0.8                       0.6                   0.6
# 1                       0.6                       0.6                   0.6
# 2                       0.6                       1.0                   0.4
#
#                   temperament
# 0   sociable, patient, docile
# 1   friendly, curious, spunky
# 2  playful, energetic, bright

# %% [markdown]
# #### Fix Group: ####
# Group is a categorical feature. If the two groups are not the same, I assign 'Miscellaneous Class'

# %%
pivoted.group_0.value_counts()
# Out:
# Toy Group                   8042
# Sporting Group              6638
# Terrier Group               5898
# Herding Group               5335
# Working Group               4173
# Non-Sporting Group          3395
# Hound Group                 3083
# Foundation Stock Service    2142
# Miscellaneous Class          202
# Name: group_0, dtype: int64

# %%
pivoted.group_1 = pivoted.group_1.fillna(pivoted.group_0)
pivoted['group'] = pivoted.apply(lambda row: row.group_0 if row.group_0== row.group_1 else 'Miscellaneous Class', axis = 1)

# %%
pivoted = pivoted.drop(['group_0', 'group_1'], axis = 1)
# Out:
#   animal_id        breed_match_0     breed_match_1              breed_0  \
# 0   A006100     Spinone Italiano               NaN     Spinone Italiano
# 1   A047759            Dachshund               NaN            Dachshund
# 2   A134067    Shetland Sheepdog               NaN    Shetland Sheepdog
# 3   A141142   Labrador Retriever  American Bulldog   Labrador Retriever
# 4   A163459  Miniature Schnauzer               NaN  Miniature Schnauzer
#
#     breed_1                                      description_0  \
# 0       NaN  The Spinone Italiano (plural: Spinoni Italiani...
# 1       NaN  The word “icon” is terribly overworked, but th...
# 2       NaN  The Shetland Sheepdog is a small, active, and ...
# 3  Pit Bull  The sturdy, well-balanced Labrador Retriever c...
# 4       NaN  Stocky, robust little dogs standing 12 to 14 i...
#
#                                        description_1  avg_height_final  \
# 0                                                NaN            55.880
# 1                                                NaN            12.700
# 2                                                NaN            33.020
# 3  The American Bulldog is a descendant of the En...            52.705
# 4                                                NaN            30.480
#
#    avg_weight_final  avg_expectancy_final  grooming_frequency_value_final  \
# 0               NaN                  11.0                             0.4
# 1          9.752236                  14.0                             0.4
# 2          9.071847                  13.0                             0.6
# 3         33.452437                  11.0                             0.3
# 4          7.030682                  13.5                             1.0
#
#    shedding_value_final  energy_level_value_final  trainability_value_final  \
# 0                   NaN                       0.8                       0.6
# 1                   0.4                       0.6                       0.6
# 2                   0.6                       0.6                       1.0
# 3                   0.7                       0.9                       0.8
# 4                   0.2                       0.6                       1.0
#
#    demeanor_value_final                                        temperament  \
# 0                   0.6                          sociable, patient, docile
# 1                   0.6                          friendly, curious, spunky
# 2                   0.4                         playful, energetic, bright
# 3                   0.8  friendly, active, outgoing, loyal, self-confident
# 4                   0.6                          friendly, smart, obedient
#
#                  group
# 0       Sporting Group
# 1          Hound Group
# 2        Herding Group
# 3  Miscellaneous Class
# 4        Terrier Group

# %%
pivoted.dtypes
# Out:
# animal_id                          object
# breed_match_0                      object
# breed_match_1                      object
# breed_0                            object
# breed_1                            object
# description_0                      object
# description_1                      object
# avg_height_final                  float64
# avg_weight_final                  float64
# avg_expectancy_final              float64
# grooming_frequency_value_final    float64
# shedding_value_final              float64
# energy_level_value_final          float64
# trainability_value_final          float64
# demeanor_value_final              float64
# temperament                        object
# group                              object
# dtype: object

# %% [markdown]
# ### Getting one dog per row: ###
# Merging pivoted with dog_breeds on animal_id so I can get each dog's shelter history.<br>
# At this point from 'dogs_breeds' I only need the shelter history data, which repeats on rows withthe same animal_id. That will allow me to join it on the right of 'pivoted'.

# %%
right = dogs_breeds[[
        'animal_id', 
        'date_of_birth', 
        'intake_type', 
        'intake_condition', 
        'age_intake', 
        'intake_datetime', 
        'intake_weekday',
        'color', 
        'time_in_shelter', 
        'outcome_subtype',
        'outcome_type',
        'outcome_datetime', 
        'outcome_weekday', 
        'stays_count', 
        'age_outcome',
       'total_time_in_shelter'
]]

# %%
mixed_dogs = pd.merge(pivoted, right, how = 'left', on = 'animal_id')
# Out:
#       animal_id       breed_match_0          breed_match_1  \
# 0       A006100    Spinone Italiano                    NaN
# 1       A047759           Dachshund                    NaN
# 2       A134067   Shetland Sheepdog                    NaN
# 3       A141142  Labrador Retriever       American Bulldog
# 4       A141142  Labrador Retriever       American Bulldog
# ...         ...                 ...                    ...
# 45070   A769043              Beagle  Australian Cattle Dog
# 45071   A769043              Beagle  Australian Cattle Dog
# 45072   A769047       Border Collie                    NaN
# 45073   A769066  Labrador Retriever                    NaN
# 45074   A769067               Boxer                    NaN
#
#                   breed_0                breed_1  \
# 0        Spinone Italiano                    NaN
# 1               Dachshund                    NaN
# 2       Shetland Sheepdog                    NaN
# 3      Labrador Retriever               Pit Bull
# 4      Labrador Retriever               Pit Bull
# ...                   ...                    ...
# 45070              Beagle  Australian Cattle Dog
# 45071              Beagle  Australian Cattle Dog
# 45072       Border Collie                    NaN
# 45073  Labrador Retriever                    NaN
# 45074               Boxer                    NaN
#
#                                            description_0  \
# 0      The Spinone Italiano (plural: Spinoni Italiani...
# 1      The word “icon” is terribly overworked, but th...
# 2      The Shetland Sheepdog is a small, active, and ...
# 3      The sturdy, well-balanced Labrador Retriever c...
# 4      The sturdy, well-balanced Labrador Retriever c...
# ...                                                  ...
# 45070  There are two Beagle varieties: those standing...
# 45071  There are two Beagle varieties: those standing...
# 45072  Borders are athletic, medium-sized herders sta...
# 45073  The sturdy, well-balanced Labrador Retriever c...
# 45074  A well-made Boxer in peak condition is an awes...
#
#                                            description_1  avg_height_final  \
# 0                                                    NaN            55.880
# 1                                                    NaN            12.700
# 2                                                    NaN            33.020
# 3      The American Bulldog is a descendant of the En...            52.705
# 4      The American Bulldog is a descendant of the En...            52.705
# ...                                                  ...               ...
# 45070  Standing between 17 to 20 inches at the should...            38.100
# 45071  Standing between 17 to 20 inches at the should...            38.100
# 45072                                                NaN            45.720
# 45073                                                NaN            54.610
# 45074                                                NaN            54.610
#
#        avg_weight_final  avg_expectancy_final  ...  intake_weekday  \
# 0                   NaN                 11.00  ...        Thursday
# 1              9.752236                 14.00  ...       Wednesday
# 2              9.071847                 13.00  ...        Saturday
# 3             33.452437                 11.00  ...        Saturday
# 4             33.452437                 11.00  ...        Saturday
# ...                 ...                   ...  ...             ...
# 45070         14.514956                 13.25  ...        Thursday
# 45071         14.514956                 13.25  ...        Thursday
# 45072         19.277676                 13.50  ...        Thursday
# 45073         30.617485                 11.00  ...        Thursday
# 45074         21.545638                 11.00  ...        Thursday
#
#                 color  time_in_shelter  outcome_subtype     outcome_type  \
# 0        Yellow/White  0 days 14:07:00              NaN  Return to Owner
# 1            Tricolor  4 days 23:17:00          Partner         Transfer
# 2         Brown/White  0 days 02:52:00              NaN  Return to Owner
# 3         Black/White  0 days 20:54:00              NaN  Return to Owner
# 4         Black/White  0 days 20:54:00              NaN  Return to Owner
# ...               ...              ...              ...              ...
# 45070       White/Red  5 days 02:34:00              NaN  Return to Owner
# 45071       White/Red  5 days 02:34:00              NaN  Return to Owner
# 45072  White/Tricolor  0 days 02:31:00              NaN  Return to Owner
# 45073     Black/White  1 days 18:18:00              NaN  Return to Owner
# 45074   Brown Brindle  0 days 19:32:00        Suffering       Euthanasia
#
#          outcome_datetime outcome_weekday stays_count age_outcome  \
# 0     2014-03-08 17:10:00        Saturday         3.0         7.0
# 1     2014-04-07 15:12:00          Monday         1.0        10.0
# 2     2013-11-16 11:54:00        Saturday         1.0        16.0
# 3     2013-11-17 11:40:00          Sunday         1.0        15.0
# 4     2013-11-17 11:40:00          Sunday         1.0        15.0
# ...                   ...             ...         ...         ...
# 45070 2018-04-03 15:14:00         Tuesday         1.0         1.0
# 45071 2018-04-03 15:14:00         Tuesday         1.0         1.0
# 45072 2018-03-29 16:01:00        Thursday         1.0         1.0
# 45073 2018-03-31 12:37:00        Saturday         1.0         1.0
# 45074 2018-03-30 13:52:00          Friday         1.0        10.0
#
#       total_time_in_shelter
# 0           2 days 23:05:00
# 1           4 days 23:17:00
# 2           0 days 02:52:00
# 3           0 days 20:54:00
# 4           0 days 20:54:00
# ...                     ...
# 45070       5 days 02:34:00
# 45071       5 days 02:34:00
# 45072       0 days 02:31:00
# 45073       1 days 18:18:00
# 45074       0 days 19:32:00
#
# [45075 rows x 32 columns]

# %%
mixed_dogs = mixed_dogs.drop(['breed_0', 'breed_1'], axis = 1)
mixed_dogs = mixed_dogs.rename({'breed_match_0': 'breed_0', 'breed_match_1': 'breed_1'}, axis = 1)

# %%
mixed_dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45075 entries, 0 to 45074
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   animal_id                       45075 non-null  object
#  1   breed_0                         45075 non-null  object
#  2   breed_1                         12334 non-null  object
#  3   description_0                   45075 non-null  object
#  4   description_1                   12334 non-null  object
#  5   avg_height_final                45075 non-null  float64
#  6   avg_weight_final                44855 non-null  float64
#  7   avg_expectancy_final            45009 non-null  float64
#  8   grooming_frequency_value_final  43988 non-null  float64
#  9   shedding_value_final            43872 non-null  float64
#  10  energy_level_value_final        44412 non-null  float64
#  11  trainability_value_final        44377 non-null  float64
#  12  demeanor_value_final            44365 non-null  float64
#  13  temperament                     45075 non-null  object
#  14  group                           45075 non-null  object
#  15  date_of_birth                   45075 non-null  datetime64[ns]
#  16  intake_type                     45075 non-null  category
#  17  intake_condition                45075 non-null  object
#  18  age_intake                      45075 non-null  float64
#  19  intake_datetime                 45075 non-null  datetime64[ns]
#  20  intake_weekday                  45075 non-null  category
#  21  color                           45075 non-null  object
#  22  time_in_shelter                 45075 non-null  timedelta64[ns]
#  23  outcome_subtype                 14280 non-null  category
#  24  outcome_type                    45074 non-null  category
#  25  outcome_datetime                45075 non-null  datetime64[ns]
#  26  outcome_weekday                 45075 non-null  category
#  27  stays_count                     45075 non-null  float64
#  28  age_outcome                     45075 non-null  float64
#  29  total_time_in_shelter           45075 non-null  timedelta64[ns]
# dtypes: category(5), datetime64[ns](3), float64(11), object(9), timedelta64[ns](2)
# memory usage: 9.2+ MB

# %% [markdown]
# ## Exploration ##

# %%
breed_counts = mixed_dogs.breed_0.value_counts().to_dict()

# %%
other = 0
to_del = []
for breed in breed_counts:
    if breed_counts[breed] < 300:
        other += breed_counts[breed]
        to_del.append(breed)
for key in to_del: 
    del breed_counts[key]
    
breed_counts['Other'] = other
breed_counts
# Out:
# {'Labrador Retriever': 6401,
#  'Chihuahua': 6285,
#  'German Shepherd Dog': 2540,
#  'Dachshund': 1628,
#  'Australian Cattle Dog': 1479,
#  'American Bulldog': 1195,
#  'Staffordshire Bull Terrier': 1035,
#  'Border Collie': 1030,
#  'Bulldog': 955,
#  'Bull Terrier': 953,
#  'Boxer': 939,
#  'Bullmastiff': 858,
#  'French Bulldog': 856,
#  'Poodle (Miniature)': 852,
#  'Miniature Bull Terrier': 846,
#  'Yorkshire Terrier': 704,
#  'Beagle': 683,
#  'Australian Shepherd': 657,
#  'Catahoula Leopard Dog': 641,
#  'Miniature Schnauzer': 640,
#  'Rat Terrier': 626,
#  'Siberian Husky': 621,
#  'Great Pyrenees': 543,
#  'Shih Tzu': 486,
#  'Rottweiler': 470,
#  'Cairn Terrier': 455,
#  'Pointer': 431,
#  'American Staffordshire Terrier': 411,
#  'Parson Russell Terrier': 381,
#  'Russell Terrier': 354,
#  'Anatolian Shepherd Dog': 354,
#  'Maltese': 342,
#  'Plott Hound': 329,
#  'Pug': 316,
#  'Other': 0}

# %%
mixed_dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45075 entries, 0 to 45074
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   animal_id                       45075 non-null  object
#  1   breed_0                         45075 non-null  object
#  2   breed_1                         12334 non-null  object
#  3   description_0                   45075 non-null  object
#  4   description_1                   12334 non-null  object
#  5   avg_height_final                45075 non-null  float64
#  6   avg_weight_final                44855 non-null  float64
#  7   avg_expectancy_final            45009 non-null  float64
#  8   grooming_frequency_value_final  43988 non-null  float64
#  9   shedding_value_final            43872 non-null  float64
#  10  energy_level_value_final        44412 non-null  float64
#  11  trainability_value_final        44377 non-null  float64
#  12  demeanor_value_final            44365 non-null  float64
#  13  temperament                     45075 non-null  object
#  14  group                           45075 non-null  object
#  15  date_of_birth                   45075 non-null  datetime64[ns]
#  16  intake_type                     45075 non-null  category
#  17  intake_condition                45075 non-null  object
#  18  age_intake                      45075 non-null  float64
#  19  intake_datetime                 45075 non-null  datetime64[ns]
#  20  intake_weekday                  45075 non-null  category
#  21  color                           45075 non-null  object
#  22  time_in_shelter                 45075 non-null  timedelta64[ns]
#  23  outcome_subtype                 14280 non-null  category
#  24  outcome_type                    45074 non-null  category
#  25  outcome_datetime                45075 non-null  datetime64[ns]
#  26  outcome_weekday                 45075 non-null  category
#  27  stays_count                     45075 non-null  float64
#  28  age_outcome                     45075 non-null  float64
#  29  total_time_in_shelter           45075 non-null  timedelta64[ns]
# dtypes: category(5), datetime64[ns](3), float64(11), object(9), timedelta64[ns](2)
# memory usage: 9.2+ MB

# %%
def plot_barchart(feature, xlabel, ylabel, title):
    feature_counts = mixed_dogs[feature].value_counts()
    plt.bar(feature_counts.keys(), feature_counts.values)
    plt.xticks(rotation = 80)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

def plot_hist(values, xlabel, ylabel, title, bins = 10, show = True):
    plt.hist(values, bins = bins)
    plt.xticks(rotation = 80)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    if show:
        plt.show()

# %%
plot_barchart('outcome_type', 'Outcome Type', 'Amount of Dogs', 'Dogs by outcome type')

# %%
plot_barchart('group', 'Group', 'Amount of Dogs', 'Dogs by Group')

# %%
plot_barchart('age_outcome', 'Age at outcome', 'Amount of Dogs', 'Dogs by Age at Outcome')

# %%
plot_hist(mixed_dogs.total_time_in_shelter.dt.days, 'Days in shelter', 'Dogs', 'Dogs by Time Spent in Shelter')

# %%
total_time_cut.mean()
# Out:
# 13.054295268651995

# %%
mixed_dogs.total_time_in_shelter.dt.days.mean()
# Out:
# 18.24740987243483

# %%
total_time_cut = mixed_dogs.loc[mixed_dogs.total_time_in_shelter.dt.days < 150, 'total_time_in_shelter'].dt.days
plot_hist(total_time_cut, 'Days in shelter', 'Dogs', 'Dogs by Time Spent in Shelter (for days < 150)', bins = 30, show = False)
plt.vlines(13, 0, 20000, color = 'red', linestyles = 'dotted', label = 'Mean of shelter time < 150 days')
plt.vlines(18, 0, 20000, color = 'green', linestyles = 'dotted', label = 'Mean of all shelter times')
plt.vlines(10, 0, 20000, color = 'orange', linestyles = 'dotted', label = 'Category separator')
plt.legend()
plt.show()

# %%
mixed_dogs.outcome_type.value_counts()
# Out:
# Adoption           20982
# Return to Owner    12248
# Transfer           10075
# Euthanasia          1468
# Died                 150
# Rto-Adopt            125
# Missing               16
# Disposal              10
# Name: outcome_type, dtype: int64

# %%
adopted.total_time_in_shelter.mean()
# Out:
# Timedelta('27 days 19:07:13.016871604')

# %%
adopted = mixed_dogs.loc[mixed_dogs.outcome_type.isin(['Adoption'])].copy()

# %%
total_time_cut = adopted.loc[adopted.total_time_in_shelter.dt.days < 150, 'total_time_in_shelter'].dt.days
plot_hist(total_time_cut, 'Days in shelter', 'Dogs', 'Dogs by Time Spent in Shelter (for days < 150)', bins = 30, show = False)
plt.vlines(total_time_cut.mean(), 0, 6000, color = 'red', linestyles = 'dotted', label = 'Mean of shelter time < 150 days')
plt.vlines(18, 0, 6000, color = 'green', linestyles = 'dotted', label = 'Mean of all shelter times')
plt.vlines(10, 0, 6000, color = 'orange', linestyles = 'dotted', label = 'Category separator')
plt.legend()
plt.show()

# %%
total_time_cut.mean()
# Out:
# 19.402301111220375

# %%
adopted['days_in_shelter'] = adopted.total_time_in_shelter.dt.days

# %%
adopted['adopted_class'] = [1 if days <= 10 else 0 for days in adopted.days_in_shelter]

# %%
adopted.corr(method = 'spearman')
# Out:
#                                 avg_height_final  avg_weight_final  \
# avg_height_final                        1.000000          0.943775
# avg_weight_final                        0.943775          1.000000
# avg_expectancy_final                   -0.794415         -0.837118
# grooming_frequency_value_final          0.233753          0.181587
# shedding_value_final                    0.609205          0.658336
# energy_level_value_final                0.537528          0.496234
# trainability_value_final                0.459543          0.444189
# demeanor_value_final                    0.130530          0.082724
# age_intake                             -0.124267         -0.119827
# stays_count                             0.062307          0.066590
# age_outcome                            -0.127557         -0.122371
# days_in_shelter                         0.166296          0.189919
# adopted_class                          -0.139380         -0.159739
#
#                                 avg_expectancy_final  \
# avg_height_final                           -0.794415
# avg_weight_final                           -0.837118
# avg_expectancy_final                        1.000000
# grooming_frequency_value_final             -0.280718
# shedding_value_final                       -0.647355
# energy_level_value_final                   -0.340792
# trainability_value_final                   -0.491873
# demeanor_value_final                       -0.266295
# age_intake                                  0.069860
# stays_count                                -0.067372
# age_outcome                                 0.072601
# days_in_shelter                            -0.187716
# adopted_class                               0.162282
#
#                                 grooming_frequency_value_final  \
# avg_height_final                                      0.233753
# avg_weight_final                                      0.181587
# avg_expectancy_final                                 -0.280718
# grooming_frequency_value_final                        1.000000
# shedding_value_final                                  0.087078
# energy_level_value_final                              0.111051
# trainability_value_final                              0.432436
# demeanor_value_final                                  0.377921
# age_intake                                            0.000295
# stays_count                                           0.000411
# age_outcome                                           0.000187
# days_in_shelter                                      -0.084743
# adopted_class                                         0.071420
#
#                                 shedding_value_final  \
# avg_height_final                            0.609205
# avg_weight_final                            0.658336
# avg_expectancy_final                       -0.647355
# grooming_frequency_value_final              0.087078
# shedding_value_final                        1.000000
# energy_level_value_final                    0.487166
# trainability_value_final                    0.485559
# demeanor_value_final                        0.175038
# age_intake                                 -0.124315
# stays_count                                 0.039482
# age_outcome                                -0.126708
# days_in_shelter                             0.146182
# adopted_class                              -0.120298
#
#                                 energy_level_value_final  \
# avg_height_final                                0.537528
# avg_weight_final                                0.496234
# avg_expectancy_final                           -0.340792
# grooming_frequency_value_final                  0.111051
# shedding_value_final                            0.487166
# energy_level_value_final                        1.000000
# trainability_value_final                        0.298535
# demeanor_value_final                            0.253634
# age_intake                                     -0.135602
# stays_count                                     0.028657
# age_outcome                                    -0.137153
# days_in_shelter                                 0.115192
# adopted_class                                  -0.099253
#
#                                 trainability_value_final  \
# avg_height_final                                0.459543
# avg_weight_final                                0.444189
# avg_expectancy_final                           -0.491873
# grooming_frequency_value_final                  0.432436
# shedding_value_final                            0.485559
# energy_level_value_final                        0.298535
# trainability_value_final                        1.000000
# demeanor_value_final                            0.418465
# age_intake                                     -0.095667
# stays_count                                     0.010389
# age_outcome                                    -0.100206
# days_in_shelter                                 0.007782
# adopted_class                                  -0.009176
#
#                                 demeanor_value_final  age_intake  stays_count  \
# avg_height_final                            0.130530   -0.124267     0.062307
# avg_weight_final                            0.082724   -0.119827     0.066590
# avg_expectancy_final                       -0.266295    0.069860    -0.067372
# grooming_frequency_value_final              0.377921    0.000295     0.000411
# shedding_value_final                        0.175038   -0.124315     0.039482
# energy_level_value_final                    0.253634   -0.135602     0.028657
# trainability_value_final                    0.418465   -0.095667     0.010389
# demeanor_value_final                        1.000000   -0.018147     0.008137
# age_intake                                 -0.018147    1.000000     0.167569
# stays_count                                 0.008137    0.167569     1.000000
# age_outcome                                -0.019656    0.958998     0.052299
# days_in_shelter                             0.018288    0.263713     0.265172
# adopted_class                              -0.021987   -0.231527    -0.237320
#
#                                 age_outcome  days_in_shelter  adopted_class
# avg_height_final                  -0.127557         0.166296      -0.139380
# avg_weight_final                  -0.122371         0.189919      -0.159739
# avg_expectancy_final               0.072601        -0.187716       0.162282
# grooming_frequency_value_final     0.000187        -0.084743       0.071420
# shedding_value_final              -0.126708         0.146182      -0.120298
# energy_level_value_final          -0.137153         0.115192      -0.099253
# trainability_value_final          -0.100206         0.007782      -0.009176
# demeanor_value_final              -0.019656         0.018288      -0.021987
# age_intake                         0.958998         0.263713      -0.231527
# stays_count                        0.052299         0.265172      -0.237320
# age_outcome                        1.000000         0.251951      -0.217244
# days_in_shelter                    0.251951         1.000000      -0.856723
# adopted_class                     -0.217244        -0.856723       1.000000

# %% [markdown]
# ## References: ##
#
# <ol>
#     <li>
#         <a href="https://www.kaggle.com/datasets/aaronschlegel/austin-animal-center-shelter-intakes-and-outcomes">Kaggle dataset - Austin Animal Center Shelter Intakes and Outcomes</a>
#     </li>
#     <li>
#         <a href="https://www.kaggle.com/datasets/mexwell/dog-breeds-dataset">Kaggle dataset - Dog Breeds Dataset AKC</a>
#     </li>
#     <li>
#         <a href="https://www.researchgate.net/publication/373805640_Predicting_Animal_Shelter_Pet_Adoption_Times_and_Feature_Importance_Analysis_using_CatBoost">Predicting Animal Shelter Pet Adoption Times and Feature Importance Analysis using CatBoost</a>
#     </li>
#     <li>
#         <a href="https://catboost.ai/en/docs/concepts/tutorials">CatBoost Functionality Introduction</a>
#     </li>
# </ol>
